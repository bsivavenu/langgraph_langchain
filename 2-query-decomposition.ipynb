# %% [markdown]
# ### 🧠 What is Query Decomposition?
# Query decomposition is the process of taking a complex, multi-part question and breaking it into simpler, atomic sub-questions that can each be retrieved and answered individually.
#
# #### ✅ Why Use Query Decomposition?
#
# - Complex queries often involve multiple concepts
#
# - LLMs or retrievers may miss parts of the original question
#
# - It enables multi-hop reasoning (answering in steps)
#
# - Allows parallelism (especially in multi-agent frameworks)

# %%
from langchain.chat_models import init_chat_model
from langchain_classic.prompts import PromptTemplate
from langchain_classic.document_loaders import TextLoader
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_core.runnables import RunnableSequence

# %%
# Step 1: Load and embed the document
loader = TextLoader("langchain_crewai_dataset.txt")
docs = loader.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
chunks = splitter.split_documents(docs)

embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(chunks, embedding)
retriever = vectorstore.as_retriever(search_type="mmr", search_kwargs={"k": 4, "lambda_mult": 0.7})

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

llm=init_chat_model(model="gpt-5-nano", model_provider="openai", temperature=0)
llm
# Out:
# ChatOpenAI(profile={'max_input_tokens': 272000, 'max_output_tokens': 128000, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x155c3c830>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x155cab800>, root_client=<openai.OpenAI object at 0x13d450b30>, root_async_client=<openai.AsyncOpenAI object at 0x155cabfe0>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
# Step 3: Query decomposition
decomposition_prompt = PromptTemplate.from_template("""
You are an AI assistant. Decompose the following complex question into 2 to 4 smaller sub-questions for better document retrieval.

Question: "{question}"

Sub-questions:
""")
decomposition_chain = decomposition_prompt | llm | StrOutputParser()

# %%
query = "How does LangChain use memory and agents compared to CrewAI?"
decomposition_question=decomposition_chain.invoke({"question": query})

# %%
print(decomposition_question)
# Out:
# Here are four sub-questions to guide document retrieval:
#
# - What memory concepts and implementations do LangChain and CrewAI expose (e.g., short-term vs. long-term memory, persistence, vector stores, retrieval methods, summarization), and how are they configured?
#
# - How are agents designed in LangChain and CrewAI (types of agents, planning vs. reactive approaches, tool invocation patterns, reasoning chains), and what built-in options do they provide?
#
# - How do memory and agents interact in practice (how past interactions influence decisions, session continuity, context/window management, and any limits or trade-offs)?
#
# - What are the customization and extension options for memory and agents in each framework (APIs, docs, examples, tooling for integration with external systems, debugging, and performance considerations)?

# %%
# Step 4: QA chain per sub-question
qa_prompt = PromptTemplate.from_template("""
Use the context below to answer the question.

Context:
{context}

Question: {input}
""")
qa_chain = create_stuff_documents_chain(llm=llm, prompt=qa_prompt)

# %%
# Step 5: Full RAG pipeline logic
def full_query_decomposition_rag_pipeline(user_query):
    # Decompose the query
    sub_qs_text = decomposition_chain.invoke({"question": user_query})
    sub_questions = [q.strip("-•1234567890. ").strip() for q in sub_qs_text.split("\n") if q.strip()]
    
    results = []
    for subq in sub_questions:
        docs = retriever.invoke(subq)
        result = qa_chain.invoke({"input": subq, "context": docs})
        results.append(f"Q: {subq}\nA: {result}")
    
    return "\n\n".join(results)

# %%
# Step 6: Run
query = "How does LangChain use memory and agents compared to CrewAI?"
final_answer = full_query_decomposition_rag_pipeline(query)
print("✅ Final Answer:\n")
print(final_answer)
# Out:
# ✅ Final Answer:
#
# Q: Sub-question 1: What memory models and storage options does LangChain offer for agents (e.g., specific memory primitives, how they store, retrieve, and summarize context)?
# A: - The provided context notes that LangChain agents use a planner-executor model with “context-aware memory use across steps.”
# - It does not specify any memory models, memory primitives, storage options, or how to store, retrieve, or summarize context.
#
# In short: There is a mention of memory capability, but no concrete details about memory primitives or storage/retrieval/summarization mechanisms in the given text. If you can share more detailed docs or specify the LangChain version, I can give a precise answer.
#
# Q: Sub-question 2: How do LangChain agents handle reasoning, planning, and tool use (e.g., ReAct-style loops), and where does memory participate in that flow?
# A: - Core pattern: LangChain agents use a planner-executor loop. The planner decides a sequence of tool invocations (actions) to achieve the goal, and the executor carries out those tools and returns observations. This loop can incorporate dynamic decision-making, branching logic, and memory across steps.
#
# - Reasoning and planning (ReAct-style): The agent performs planning that combines reasoning about the goal with deciding which tool to invoke next. In a ReAct-like loop, the agent repeatedly alternates: plan (reason about the next action or subgoal), execute (call the chosen tool), observe the result, then plan again based on what happened.
#
# - Tool use: Tools are invoked according to the current plan by the executor. Each tool call yields an observation or result that informs the next planning step.
#
# - Memory and where it participates: Memory is used across steps to maintain context—previous observations, tool results, intermediate facts, and the overall state of the task. This context-aware memory informs future planning decisions, enabling dynamic branching, avoiding repetition, and enabling continuity across the reasoning-execution cycles. In short, memory feeds the planner with history and context, and is updated by the executor with every tool result.
#
# Q: Sub-question 3: What is CrewAI’s approach to memory and agent architecture (memory types, persistence/retrieval, and how agents reason and act)?
# A: - The provided context does not specify CrewAI’s memory types, persistence/retrieval mechanisms, or the internal reasoning/acting model.
# - What is described:
#   - Each agent has a defined purpose, a goal, and a set of tools.
#   - Agents operate semi-independently within a collaborative framework and follow structured workflows.
#   - Roles include examples like researcher, planner, and executor, all contributing to the crew’s objective.
# - Inference (not stated explicitly in the text):
#   - The architecture is a role-based, workflow-driven multi-agent system designed for coordination and task division.
#   - Reasoning and action likely emerge from role-specific responsibilities (e.g., planners reason about plans, researchers gather information, executors carry out tasks with tools) within the overall workflow, aided by collaboration with other crew members.
# - If you want a concrete design outline (memory, persistence, reasoning) I can propose one, but the current material does not prescribe specifics.
#
# Q: Sub-question 4: What are the key architectural and capability differences between LangChain and CrewAI regarding memory handling and agent design, including typical use cases and trade-offs?
# A: Here are the key architectural and capability differences, with typical use cases and trade-offs, focused on memory handling and agent design as described in the provided context.
#
# - Architectural focus
#   - LangChain
#     - Agent design: planner-executor model. The agent plans a sequence of tool invocations to reach a goal, with support for dynamic decision-making, branching, and context-aware memory across steps.
#     - Memory role: memory is a built-in capability used to inform planning and decisions as the plan unfolds.
#   - CrewAI
#     - Agent design: role-based collaboration layer. CrewAI coordinates multiple agents, each with defined roles, to collaborate toward a shared objective.
#     - Memory role: not described in the provided context. The emphasis is on coordinating roles; memory handling is not explicitly highlighted as a core feature (at least in the given text).
#
# - Memory handling
#   - LangChain
#     - Explicit emphasis on context-aware memory across steps, enabling the planner to reuse context and guide subsequent tool calls.
#   - CrewAI
#     - Memory model is not specified in the provided context. The focus is on collaboration among role-specific agents, rather than on a centralized memory mechanism for planning steps.
#
# - Typical use cases
#   - LangChain
#     - Tasks that require structured, multi-step reasoning and sequential tool usage.
#     - Scenarios with memory across steps to maintain context (e.g., data gathering, API orchestration, complex reasoning chains).
#   - CrewAI
#     - Multi-agent tasks requiring diverse perspectives and governance from different roles.
#     - Collaborative workflows where accountability and role-specific input are important (e.g., reviews, design-by-committee, multi-stakeholder decision making).
#
# - Trade-offs
#   - LangChain
#     - Strengths: robust automatic planning of tool invocations, deep memory for context, dynamic branching, and self-contained reasoning within a single (planner-based) agent.
#     - Trade-offs: can be complex to implement and maintain; planning logic may become intricate with many branches; primarily suited to single-agent or tightly coupled planning scenarios.
#   - CrewAI
#     - Strengths: strong support for distributed collaboration across defined roles, which can improve reliability, checks, and coverage of expertise.
#     - Trade-offs: potential coordination overhead and slower throughput due to multi-agent collaboration; memory/continuity mechanisms are not described and may depend on how the ensemble is composed.
#
# - Hybrid integration (from the provided context)
#   - The systems can be combined: LangChain handles retrieval and tool wrapping, while CrewAI handles role-based collaboration. This allows building a hybrid workflow where a planner-oriented, memory-capable LangChain component works alongside a role-coordinating CrewAI component.
#
# In short, LangChain centers on planning and memory-rich, multi-step tool usage within (often) a single-agent framework, while CrewAI centers on coordinating multiple role-based agents. LangChain’s memory is explicit and core to its design; CrewAI’s memory model isn’t specified in the context, with the emphasis on collaborative governance and orchestration instead. When used together, you get a hybrid that leverages LangChain’s retrieval/tooling and CrewAI’s collaborative structure.
